# %% [markdown]
# ## Домашнее задание 3 (10 баллов)
#
# ## НИУ ВШЭ, 2020-21 учебный год

# %% [markdown]
# ### О задании

# %% [markdown]
# В этом домашнем задании вы получите опыт подготовки данных и EDA (Exploratory Data Analysis), приблизившись к реальной работе с данными с помощью уже знакомых вам инструментов: numpy, pandas, matplotlib и seaborn.

# %% [markdown]
# Вы будет работать с задачей кредитного скоринга (оценка надёжности клиента). Предоставляются данные о 1000 клиентов, про которых известно около 20 признаков и положительная или отрицательная оценка в качестве кредитуемого. Эти данные нужно будет подготовить, исследовать (в том числе с помощью средств визуализации) и даже попробовать предложить какую-нибудь формулу для условной оценки надёжности клиентов исходя из предоставленных данных. Описание данных:
# https://www.rdocumentation.org/packages/evtree/versions/1.0-8/topics/GermanCredit
#
# Каждый построенный график необходимо красиво оформить - для этого требуется как минимум указать его название, а также отметить, что изображено по каждой из осей.
# Также по каждому графику ожидается небольшой комментарий с выводами.
#
# *Функции, которые могут пригодиться при оформлении графиков: `.show()`, `.title()`, `.xlabel()`, `.ylabel()`*

# %%
import pandas as pd

# %% [markdown]
# ### Задание 1 (0.0 балла)

# %% [markdown]
# Прочитайте средствами pandas файл с данными по ссылке https://raw.githubusercontent.com/PersDep/data-mining-intro-2021/main/hw03-EDA-data/german_credit.csv. Выведите базовое представление таблицы (первые 5 и последние 5 строк, размер).

# %%
# your code here
data = pd.read_csv('https://raw.githubusercontent.com/PersDep/data-mining-intro-2021/main/hw03-EDA-data/german_credit.csv')
data.head()
# Out:
#                 status  duration                               credit_history  \
# 0  no checking account        18      all credits at this bank paid back duly
# 1  no checking account         9      all credits at this bank paid back duly
# 2           ... < 0 DM        12  no credits taken/all credits paid back duly
# 3  no checking account        12      all credits at this bank paid back duly
# 4  no checking account        12      all credits at this bank paid back duly
#
#       purpose  amount                     savings employment_duration  \
# 0  car (used)    1049  unknown/no savings account              < 1 yr
# 1      others    2799  unknown/no savings account    1 <= ... < 4 yrs
# 2  retraining     841               ... <  100 DM    4 <= ... < 7 yrs
# 3      others    2122  unknown/no savings account    1 <= ... < 4 yrs
# 4      others    2171  unknown/no savings account    1 <= ... < 4 yrs
#
# ...

# %%
data.tail()
# Out:
#                                          status  duration  \
# 995                         no checking account        24
# 996                         no checking account        24
# 997  ... >= 200 DM / salary for at least 1 year        21
# 998                                  ... < 0 DM        12
# 999                         no checking account        30
#
#                                   credit_history              purpose  amount  \
# 995  no credits taken/all credits paid back duly  furniture/equipment    1987
# 996  no credits taken/all credits paid back duly               others    2303
# 997      all credits at this bank paid back duly               others   12680
# 998  no credits taken/all credits paid back duly  furniture/equipment    6468
# 999  no credits taken/all credits paid back duly           car (used)    6350
#
#                         savings employment_duration installment_rate  \
# 995  unknown/no savings account    1 <= ... < 4 yrs   25 <= ... < 35
# ...

# %%
data.shape
# Out:
# (1000, 21)

# %% [markdown]
# ### Задание 2 (0.5 балла)

# %% [markdown]
# Определите, есть ли пропуски в данных. Разделите признаки на количественные, бинарные, порядковые и категориальные.

# %%
data.isna().sum()
# Out:
# status                     0
# duration                   0
# credit_history             0
# purpose                    0
# amount                     0
# savings                    0
# employment_duration        0
# installment_rate           0
# personal_status_sex        0
# other_debtors              0
# present_residence          0
# property                   0
# age                        0
# other_installment_plans    0
# housing                    0
# number_credits             0
# job                        0
# people_liable              0
# telephone                  0
# foreign_worker             0
# credit_risk                0
# dtype: int64

# %% [markdown]
# ### Задание 3 (0.5 балла)

# %% [markdown]
# Выведите среднюю сумму кредита (колонка amount) в каждой категории (колонка purpose), воспользовавшись методом groupby.

# %%
data.groupby("purpose")['amount'].mean()
# Out:
# purpose
# business               8209.333333
# car (new)              5370.223301
# car (used)             3066.983425
# domestic appliances    2728.090909
# furniture/equipment    2487.685714
# others                 3062.948718
# radio/television       1498.000000
# repairs                3180.400000
# retraining             4158.041237
# vacation               1205.888889
# Name: amount, dtype: float64

# %% [markdown]
# ### Задание 4 (0.5 балла)

# %% [markdown]
# Какой процент клиентов моложе 30 лет (колонка age) снимает жилье (колонка housing)? А какой процент клиентов старше 40 лет снимает жилье?

# %%
count_30 = sum(data.age < 30)
count_40 = sum(data.age > 40)
# Out:
# 701

# %%
sum((data['housing'] == 'rent') & (data['age'] < 30)) / count_30
# Out:
# 0.6666666666666666

# %%
sum((data['housing'] == 'rent') & (data['age'] > 40)) / count_40
# Out:
# 0.26390870185449355

# %% [markdown]
# ### Задание 5 (0.5 балла)

# %% [markdown]
#  У скольких иностранцев (foreign_worker) число кредитов (number_credits) больше 3?

# %%
count_foreign = sum((data.foreign_worker == 'yes') & (data.number_credits == '4-5')) 
count_foreign
# Out:
# 1

# %%
count_foreign += sum((data.foreign_worker == 'yes') & (data.number_credits == '>= 6'))
count_foreign
# Out:
# 1

# %% [markdown]
# ### Задание 6 (1 балл)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Используя numpy и matplotlib, начнём с тренировки: постройте график функций $sin(x)$ и $cos(x)$ от $-\pi$ до $\pi$ из 100 точек c легендой и сеткой. Используйте для линий разные цвета, одна из них пусть будет пунктирной. Результат в этом и следующих заданиях на построение графиков должен получиться примерно как на картинке. Содержание подписей не должно обязательно совпадать, однако осмысленные подписи должны присутствовать на графиках.

# %%
x = np.arange(-np.pi, np.pi, np.pi/50)
y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x, y1, label = 'sin') 
plt.plot(x, y2, linestyle = '--', label = 'cos')


plt.title('sin() & cos() graph')
plt.xlabel('x')
plt.ylabel('cos & sin')
plt.legend()
plt.grid()

# %% [markdown]
# ### Задание 7 (1 балл)

# %% [markdown]
# Рассмотрим сравнительное количество положительных и отрицательных кейсов в зависимости от размера текущего счёта. Постройте зеркальные горизонтальные гистограммы.

# %%
df = data.groupby(['status', 'credit_risk']).size().reset_index(name='count')

x0 = df['status'].unique()
y1 = df[df['credit_risk'] == 'good']['count']
y2 = df[df['credit_risk'] == 'bad']['count']

plt.barh(x0, y2, facecolor='r', label = 'bad')
plt.barh(x0, -y1, facecolor='g', label = 'good')
plt.legend()
plt.show()

# %%
df
# Out:
#                                        status credit_risk  count
# 0                                  ... < 0 DM         bad    105
# 1                                  ... < 0 DM        good    164
# 2  ... >= 200 DM / salary for at least 1 year         bad     46
# 3  ... >= 200 DM / salary for at least 1 year        good    348
# 4                            0<= ... < 200 DM         bad     14
# 5                            0<= ... < 200 DM        good     49
# 6                         no checking account         bad    135
# 7                         no checking account        good    139

# %% [markdown]
# ### Задание 8  (0.5 балла)

# %%
import seaborn as sns

# %% [markdown]
# Теперь постройте гистограмму для сравнения количества положительных и отрицательных кейсов в зависимости от размера сберегательного счёта с помощью seaborn. Какой способ вам больше нравится с точки зрения трудоёмкости написания кода? А с точки зрения восприятия результата?

# %%
df1 = data.groupby(['savings', 'credit_risk']).size().reset_index(name='count')
df1
# Out:
#                       savings credit_risk  count
# 0               ... <  100 DM         bad     34
# 1               ... <  100 DM        good     69
# 2              ... >= 1000 DM         bad     32
# 3              ... >= 1000 DM        good    151
# 4        100 <= ... <  500 DM         bad     11
# 5        100 <= ... <  500 DM        good     52
# 6        500 <= ... < 1000 DM         bad      6
# 7        500 <= ... < 1000 DM        good     42
# 8  unknown/no savings account         bad    217
# 9  unknown/no savings account        good    386

# %%
g = sns.barplot(x='savings', y='count', hue='credit_risk', data=df1, palette='Paired', saturation=0.8)
sns.set(rc={'figure.figsize':(10,10)})
plt.show()

# %% [markdown]
# ### Задание 9  (1 балл)

# %% [markdown]
# seaborn легко позволяет добавить ещё больше информации на один график. Для каждого размера сберегательного счёта мы можем оценить не только количество положительных и отрицательных кейсов, но и их распределение по возрасту, например. Постройте подходящую для этого визуализацию.

# %%
df2 = data.groupby(['savings', 'credit_risk', 'age']).size().reset_index(name='count')
df2
# Out:
#                         savings credit_risk  age  count
# 0                 ... <  100 DM         bad   20      1
# 1                 ... <  100 DM         bad   21      2
# 2                 ... <  100 DM         bad   22      2
# 3                 ... <  100 DM         bad   23      1
# 4                 ... <  100 DM         bad   24      4
# ..                          ...         ...  ...    ...
# 281  unknown/no savings account        good   67      2
# 282  unknown/no savings account        good   68      1
# 283  unknown/no savings account        good   70      1
# 284  unknown/no savings account        good   74      3
# 285  unknown/no savings account        good   75      1
#
# [286 rows x 4 columns]

# %%
plt.figure(figsize=(1000, 100))
sns.catplot(x="savings", y="age", hue="credit_risk", data=df2, kind="violin", split = True, cut=2)
plt.show()

# %% [markdown]
# ### Задание 11  (0.5 балла)

# %%
data.head()
# Out:
#                 status  duration                               credit_history  \
# 0  no checking account        18      all credits at this bank paid back duly
# 1  no checking account         9      all credits at this bank paid back duly
# 2           ... < 0 DM        12  no credits taken/all credits paid back duly
# 3  no checking account        12      all credits at this bank paid back duly
# 4  no checking account        12      all credits at this bank paid back duly
#
#       purpose  amount                     savings employment_duration  \
# 0  car (used)    1049  unknown/no savings account              < 1 yr
# 1      others    2799  unknown/no savings account    1 <= ... < 4 yrs
# 2  retraining     841               ... <  100 DM    4 <= ... < 7 yrs
# 3      others    2122  unknown/no savings account    1 <= ... < 4 yrs
# 4      others    2171  unknown/no savings account    1 <= ... < 4 yrs
#
# ...

# %% [markdown]
# Не менее полезной иногда может быть диаграмма рассеяния. Постройте такую диаграмму с продолжительностью и размерами кредитов в качестве осей. Обозначьте положительные и отрицательные кейсы разными цветами.

# %%
sns.relplot(data=data, x="amount", y="duration", hue="credit_risk")

# %% [markdown]
# ### Задание 12  (1 балл)

# %% [markdown]
# Продвинемся глубже. Постройте 3D версию диаграммы рассеяния, добавив ось с возрастом.

# %%
sns.set(style = "darkgrid")

fig = plt.figure()
ax = fig.add_subplot( projection = '3d')

x = data.amount
y = data.duration
z = data.age

ax.set_xlabel("amount")
ax.set_ylabel("duration")
ax.set_zlabel("age")

ax.scatter(x, y, z)

# %% [markdown]
# ### Задание 13  (0.5 балла)

# %% [markdown]
# Представьте все порядковые и бинарные признаки в виде числовых значений {0, ..., n - 1}, где n это количество значений признака. Избавьтесь от категориальных признаков.

# %%
data1 = data.copy()
data1
# Out:
#                                          status  duration  \
# 0                           no checking account        18
# 1                           no checking account         9
# 2                                    ... < 0 DM        12
# 3                           no checking account        12
# 4                           no checking account        12
# ..                                          ...       ...
# 995                         no checking account        24
# 996                         no checking account        24
# 997  ... >= 200 DM / salary for at least 1 year        21
# 998                                  ... < 0 DM        12
# 999                         no checking account        30
#
#                                   credit_history              purpose  amount  \
# 0        all credits at this bank paid back duly           car (used)    1049
# 1        all credits at this bank paid back duly               others    2799
# ...

# %%
data1.status = data1.status.map({'... >= 200 DM / salary for at least 1 year': 1,
                 'no checking account': 0, '... < 0 DM': 2,
                '0<= ... < 200 DM': 3})

# %%
data1.credit_history = data1.credit_history.map({'no credits taken/all credits paid back duly': 0,
                                                 'all credits at this bank paid back duly': 1,
                                                 'existing credits paid back duly till now': 2,
                                                 'critical account/other credits elsewhere': 3,
                                                 'delay in paying off in the past': 4})

# %%
data1.purpose = data1.purpose.map({'furniture/equipment': 0,
                                  'others': 1, 'car (used)': 2,
                                  'car (new)': 3, 'retraining': 4,
                                  'repairs': 5, 'repairs': 6,
                                  'domestic appliances': 7,
                                  'radio/television': 8, 'business': 9,
                                  'vacation': 10})

# %%
data1.savings = data1.savings.map({'unknown/no savings account': 0,
                                  '... >= 1000 DM': 1, '... <  100 DM': 2,
                                  '100 <= ... <  500 DM': 3,
                                   '500 <= ... < 1000 DM': 4})

# %%
data1.employment_duration = data1.employment_duration.map({'unemployed': 0,
                                                           '< 1 yr': 1, '4 <= ... < 7 yrs': 2,
                                                           '>= 7 yrs': 3,
                                                           '1 <= ... < 4 yrs': 4})

# %%
data1.personal_status_sex = data1.personal_status_sex.map({'female : single': 0,
                                                           'male : divorced/separated': 1,
                                                           'female : non-single or male : single': 2,
                                                           'male : married/widowed': 3})

# %%
data1.installment_rate = data1.installment_rate.map({'< 20': 0,
                                                     '20 <= ... < 25': 1,
                                                     '25 <= ... < 35': 2,
                                                     '>= 35': 3})

# %%
data1.other_debtors = data1.other_debtors.map({'none': 0,
                                               'guarantor': 1,
                                               'co-applicant': 2})

# %%
data1.property = data1.property.map({'unknown / no property': 0,
                                     'car or other': 1,
                                     'building soc. savings agr./life insurance': 2,
                                     'real estate': 3})

# %%
data1.other_installment_plans = data1.other_installment_plans.map({'stores': 0,
                                                                   'bank': 1,
                                                                   'none': 2})

# %%
data1.housing = data1.housing.map({'rent': 0,
                                   'for free': 1,
                                   'own': 2})

# %%
data1.number_credits = data1.number_credits.map({'1': 0,
                                                 '2-3': 1,
                                                 '4-5': 2,
                                                 '>= 6': 3})

# %%
data1.job = data1.job.map({'unemployed/unskilled - non-resident': 0,
                           'unskilled - resident': 1,
                           'manager/self-empl./highly qualif. employee': 2,
                           'skilled employee/official': 3})

# %%
data1.people_liable = data1.people_liable.map({'0 to 2': 0,
                                               '3 or more': 1})

# %%
data1.telephone = data1.telephone.map({'no': 0,
                                       'yes (under customer name)': 1})

# %%
data1.foreign_worker = data1.foreign_worker.map({'no': 0,
                                                 'yes': 1})

# %%
data1.present_residence = data1.present_residence.map({'< 1 yr': 0,
                                                       '1 <= ... < 4 yrs': 1,
                                                       '4 <= ... < 7 yrs': 2,
                                                       '>= 7 yrs': 3})

# %%
data_t = data1.copy()

# %%
data_t.present_residence.value_counts()
# Out:
# 3    413
# 1    308
# 2    149
# 0    130
# Name: present_residence, dtype: int64

# %%
data_t['res'] = (data_t.status + data_t.credit_history + 
                 data_t.purpose + data_t.amount/10000 + data_t.savings + 
                 data_t.employment_duration + data_t.installment_rate + 
                 data_t.personal_status_sex + data_t.other_debtors + 
                 data_t.present_residence + data_t.age/10 + data_t.other_installment_plans + 
                 data_t.housing + data_t.number_credits + data_t.job + data_t.people_liable + 
                 data_t.telephone + data_t.foreign_worker)

# %%
data_t.head(30)
# Out:
#     status  duration  credit_history  purpose  amount  savings  \
# 0        0        18               1        2    1049        0
# 1        0         9               1        1    2799        0
# 2        2        12               0        4     841        2
# 3        0        12               1        1    2122        0
# 4        0        12               1        1    2171        0
# 5        0        10               1        1    2241        0
# 6        0         8               1        1    3398        0
# 7        0         6               1        1    1361        0
# 8        1        18               1        0    1098        0
# 9        2        24               0        0    3758        3
# 10       0        11               1        1    3905        0
# 11       0        30               1        3    6187        2
# 12       0         6               1        0    1957        0
# 13       2        48               2        9    7582        2
# ...

# %% [markdown]
# ### Задание 14  (2 балла)

# %% [markdown]
# По результатам предыдущего задания у вас должна получиться таблица, в которой все признаки так или иначе представлены числовыми значениями. Попробуйте придумать на основе проведённых исследований данных какую-нибудь формулу, связывающую целевую переменную с признаками, не используя готовых инструментов машинного обучения. По желанию вы можете исключить ещё какие-то признаки, или, наоборот, сформировать новые на основе имеющихся. Возможно, вы захотите отмасштабировать большие наборы численных значений некоторых признаков с помощью интервалов. Цель: реализовать функцию, которая будет принимать на вход набор признаков для объекта выборки и возвращать прогноз целевой переменной (0 или 1). Например, вы можете просто сложить все признаки и возращать ноль, если сумма отрицательная, а в противном случае единицу. Но наверняка можно придумать лучше!
# Данные уже разделены на набор для обучения, который вы можете использовать как угодно, и тестовый, на котором нужно будет проверить вашу точность. Постарайтесь достичь точности хотя бы 0.6.

# %%
def predict(Xtest: np.array) -> np.array:
    if Xtest[22] < 20:
        return 'bad'
    if Xtest[22] > 30:
        return 'bad'
    return 'good'

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X = data_t.drop('credit_risk', 1).values
y = data_t['credit_risk'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=10)

# your code here
accuracy_score(y_test, predict(X_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-593-d3994f9168c6> in <module>
#      14
#      15 # your code here
# ---> 16 accuracy_score(y_test, predict(X_test))
#
# <ipython-input-593-d3994f9168c6> in predict(Xtest)
#       1 def predict(Xtest: np.array) -> np.array:
# ----> 2     if Xtest[22] < 20:
#       3         return 'bad'
#       4     if Xtest[22] > 30:
#       5         return 'bad'
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
